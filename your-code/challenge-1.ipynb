# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
# import libraries
import pandas as pd
import numpy as np
import re

# %% [markdown]
# #### Import data set.
#
# Import `pokemon_stats` table from the file `Pokemon.csv` from the `data` folder. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set from Ironhack's database
pokemon = pd.read_csv('/Users/ayubpathan/Desktop/ironhack/Week2/lab-df-calculation-and-transformation/data/Pokemon.csv')
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Extract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# your code here
type1_2 = pokemon[['Type 1', 'Type 2']].values.tolist()
type1_2
# Out:
# [['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Fire', 'Flying'],
#  ['Fire', 'Dragon'],
#  ['Fire', 'Flying'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Bug', nan],
#  ['Bug', nan],
#  ['Bug', 'Flying'],
#  ['Bug', 'Poison'],
#  ['Bug', 'Poison'],
#  ['Bug', 'Poison'],
#  ['Bug', 'Poison'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Poison', nan],
#  ['Poison', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Ground', nan],
#  ['Ground', nan],
#  ['Poison', nan],
#  ['Poison', nan],
#  ['Poison', 'Ground'],
#  ['Poison', nan],
#  ['Poison', nan],
#  ['Poison', 'Ground'],
#  ['Fairy', nan],
#  ['Fairy', nan],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Normal', 'Fairy'],
#  ['Normal', 'Fairy'],
#  ['Poison', 'Flying'],
#  ['Poison', 'Flying'],
#  ['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Bug', 'Grass'],
#  ['Bug', 'Grass'],
#  ['Bug', 'Poison'],
#  ['Bug', 'Poison'],
#  ['Ground', nan],
#  ['Ground', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', 'Fighting'],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Water', 'Poison'],
#  ['Water', 'Poison'],
#  ['Rock', 'Ground'],
#  ['Rock', 'Ground'],
#  ['Rock', 'Ground'],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Water', 'Psychic'],
#  ['Water', 'Psychic'],
#  ['Water', 'Psychic'],
#  ['Electric', 'Steel'],
#  ['Electric', 'Steel'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Water', nan],
#  ['Water', 'Ice'],
#  ['Poison', nan],
#  ['Poison', nan],
#  ['Water', nan],
#  ['Water', 'Ice'],
#  ['Ghost', 'Poison'],
#  ['Ghost', 'Poison'],
#  ['Ghost', 'Poison'],
#  ['Ghost', 'Poison'],
#  ['Rock', 'Ground'],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Grass', 'Psychic'],
#  ['Grass', 'Psychic'],
#  ['Ground', nan],
#  ['Ground', nan],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Normal', nan],
#  ['Poison', nan],
#  ['Poison', nan],
#  ['Ground', 'Rock'],
#  ['Ground', 'Rock'],
#  ['Normal', nan],
#  ['Grass', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', 'Psychic'],
#  ['Psychic', 'Fairy'],
#  ['Bug', 'Flying'],
#  ['Ice', 'Psychic'],
#  ['Electric', nan],
#  ['Fire', nan],
#  ['Bug', nan],
#  ['Bug', 'Flying'],
#  ['Normal', nan],
#  ['Water', nan],
#  ['Water', 'Flying'],
#  ['Water', 'Dark'],
#  ['Water', 'Ice'],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Water', nan],
#  ['Electric', nan],
#  ['Fire', nan],
#  ['Normal', nan],
#  ['Rock', 'Water'],
#  ['Rock', 'Water'],
#  ['Rock', 'Water'],
#  ['Rock', 'Water'],
#  ['Rock', 'Flying'],
#  ['Rock', 'Flying'],
#  ['Normal', nan],
#  ['Ice', 'Flying'],
#  ['Electric', 'Flying'],
#  ['Fire', 'Flying'],
#  ['Dragon', nan],
#  ['Dragon', nan],
#  ['Dragon', 'Flying'],
#  ['Psychic', nan],
#  ['Psychic', 'Fighting'],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Bug', 'Flying'],
#  ['Bug', 'Flying'],
#  ['Bug', 'Poison'],
#  ['Bug', 'Poison'],
#  ['Poison', 'Flying'],
#  ['Water', 'Electric'],
#  ['Water', 'Electric'],
#  ['Electric', nan],
#  ['Fairy', nan],
#  ['Normal', 'Fairy'],
#  ['Fairy', nan],
#  ['Fairy', 'Flying'],
#  ['Psychic', 'Flying'],
#  ['Psychic', 'Flying'],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Electric', 'Dragon'],
#  ['Grass', nan],
#  ['Water', 'Fairy'],
#  ['Water', 'Fairy'],
#  ['Rock', nan],
#  ['Water', nan],
#  ['Grass', 'Flying'],
#  ['Grass', 'Flying'],
#  ['Grass', 'Flying'],
#  ['Normal', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Bug', 'Flying'],
#  ['Water', 'Ground'],
#  ['Water', 'Ground'],
#  ['Psychic', nan],
#  ['Dark', nan],
#  ['Dark', 'Flying'],
#  ['Water', 'Psychic'],
#  ['Ghost', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Normal', 'Psychic'],
#  ['Bug', nan],
#  ['Bug', 'Steel'],
#  ['Normal', nan],
#  ['Ground', 'Flying'],
#  ['Steel', 'Ground'],
#  ['Steel', 'Ground'],
#  ['Fairy', nan],
#  ['Fairy', nan],
#  ['Water', 'Poison'],
#  ['Bug', 'Steel'],
#  ['Bug', 'Steel'],
#  ['Bug', 'Rock'],
#  ['Bug', 'Fighting'],
#  ['Bug', 'Fighting'],
#  ['Dark', 'Ice'],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Fire', nan],
#  ['Fire', 'Rock'],
#  ['Ice', 'Ground'],
#  ['Ice', 'Ground'],
#  ['Water', 'Rock'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Ice', 'Flying'],
#  ['Water', 'Flying'],
#  ['Steel', 'Flying'],
#  ['Dark', 'Fire'],
#  ['Dark', 'Fire'],
#  ['Dark', 'Fire'],
#  ['Water', 'Dragon'],
#  ['Ground', nan],
#  ['Ground', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Ice', 'Psychic'],
#  ['Electric', nan],
#  ['Fire', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Electric', nan],
#  ['Fire', nan],
#  ['Water', nan],
#  ['Rock', 'Ground'],
#  ['Rock', 'Ground'],
#  ['Rock', 'Dark'],
#  ['Rock', 'Dark'],
#  ['Psychic', 'Flying'],
#  ['Fire', 'Flying'],
#  ['Psychic', 'Grass'],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Grass', 'Dragon'],
#  ['Fire', nan],
#  ['Fire', 'Fighting'],
#  ['Fire', 'Fighting'],
#  ['Fire', 'Fighting'],
#  ['Water', nan],
#  ['Water', 'Ground'],
#  ['Water', 'Ground'],
#  ['Water', 'Ground'],
#  ['Dark', nan],
#  ['Dark', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Bug', nan],
#  ['Bug', nan],
#  ['Bug', 'Flying'],
#  ['Bug', nan],
#  ['Bug', 'Poison'],
#  ['Water', 'Grass'],
#  ['Water', 'Grass'],
#  ['Water', 'Grass'],
#  ['Grass', nan],
#  ['Grass', 'Dark'],
#  ['Grass', 'Dark'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Water', 'Flying'],
#  ['Water', 'Flying'],
#  ['Psychic', 'Fairy'],
#  ['Psychic', 'Fairy'],
#  ['Psychic', 'Fairy'],
#  ['Psychic', 'Fairy'],
#  ['Bug', 'Water'],
#  ['Bug', 'Flying'],
#  ['Grass', nan],
#  ['Grass', 'Fighting'],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Bug', 'Ground'],
#  ['Bug', 'Flying'],
#  ['Bug', 'Ghost'],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Normal', 'Fairy'],
#  ['Rock', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Dark', 'Ghost'],
#  ['Dark', 'Ghost'],
#  ['Steel', 'Fairy'],
#  ['Steel', 'Fairy'],
#  ['Steel', 'Rock'],
#  ['Steel', 'Rock'],
#  ['Steel', 'Rock'],
#  ['Steel', nan],
#  ['Fighting', 'Psychic'],
#  ['Fighting', 'Psychic'],
#  ['Fighting', 'Psychic'],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Bug', nan],
#  ['Bug', nan],
#  ['Grass', 'Poison'],
#  ['Poison', nan],
#  ['Poison', nan],
#  ['Water', 'Dark'],
#  ['Water', 'Dark'],
#  ['Water', 'Dark'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Fire', 'Ground'],
#  ['Fire', 'Ground'],
#  ['Fire', 'Ground'],
#  ['Fire', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Normal', nan],
#  ['Ground', nan],
#  ['Ground', 'Dragon'],
#  ['Ground', 'Dragon'],
#  ['Grass', nan],
#  ['Grass', 'Dark'],
#  ['Normal', 'Flying'],
#  ['Dragon', 'Flying'],
#  ['Dragon', 'Fairy'],
#  ['Normal', nan],
#  ['Poison', nan],
#  ['Rock', 'Psychic'],
#  ['Rock', 'Psychic'],
#  ['Water', 'Ground'],
#  ['Water', 'Ground'],
#  ['Water', nan],
#  ['Water', 'Dark'],
#  ['Ground', 'Psychic'],
#  ['Ground', 'Psychic'],
#  ['Rock', 'Grass'],
#  ['Rock', 'Grass'],
#  ['Rock', 'Bug'],
#  ['Rock', 'Bug'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Ghost', nan],
#  ['Ghost', nan],
#  ['Ghost', nan],
#  ['Ghost', nan],
#  ['Ghost', nan],
#  ['Grass', 'Flying'],
#  ['Psychic', nan],
#  ['Dark', nan],
#  ['Dark', nan],
#  ['Psychic', nan],
#  ['Ice', nan],
#  ['Ice', nan],
#  ['Ice', nan],
#  ['Ice', 'Water'],
#  ['Ice', 'Water'],
#  ['Ice', 'Water'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', 'Rock'],
#  ['Water', nan],
#  ['Dragon', nan],
#  ['Dragon', nan],
#  ['Dragon', 'Flying'],
#  ['Dragon', 'Flying'],
#  ['Steel', 'Psychic'],
#  ['Steel', 'Psychic'],
#  ['Steel', 'Psychic'],
#  ['Steel', 'Psychic'],
#  ['Rock', nan],
#  ['Ice', nan],
#  ['Steel', nan],
#  ['Dragon', 'Psychic'],
#  ['Dragon', 'Psychic'],
#  ['Dragon', 'Psychic'],
#  ['Dragon', 'Psychic'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Ground', nan],
#  ['Ground', 'Fire'],
#  ['Dragon', 'Flying'],
#  ['Dragon', 'Flying'],
#  ['Steel', 'Psychic'],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Grass', 'Ground'],
#  ['Fire', nan],
#  ['Fire', 'Fighting'],
#  ['Fire', 'Fighting'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', 'Steel'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Normal', nan],
#  ['Normal', 'Water'],
#  ['Bug', nan],
#  ['Bug', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Rock', nan],
#  ['Rock', nan],
#  ['Rock', 'Steel'],
#  ['Rock', 'Steel'],
#  ['Bug', nan],
#  ['Bug', 'Grass'],
#  ['Bug', 'Ground'],
#  ['Bug', 'Steel'],
#  ['Bug', 'Flying'],
#  ['Bug', 'Flying'],
#  ['Bug', 'Flying'],
#  ['Electric', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Water', nan],
#  ['Water', 'Ground'],
#  ['Normal', nan],
#  ['Ghost', 'Flying'],
#  ['Ghost', 'Flying'],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', 'Fighting'],
#  ['Ghost', nan],
#  ['Dark', 'Flying'],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Psychic', nan],
#  ['Poison', 'Dark'],
#  ['Poison', 'Dark'],
#  ['Steel', 'Psychic'],
#  ['Steel', 'Psychic'],
#  ['Rock', nan],
#  ['Psychic', 'Fairy'],
#  ['Normal', nan],
#  ['Normal', 'Flying'],
#  ['Ghost', 'Dark'],
#  ['Dragon', 'Ground'],
#  ['Dragon', 'Ground'],
#  ['Dragon', 'Ground'],
#  ['Dragon', 'Ground'],
#  ['Normal', nan],
#  ['Fighting', nan],
#  ['Fighting', 'Steel'],
#  ['Fighting', 'Steel'],
#  ['Ground', nan],
#  ['Ground', nan],
#  ['Poison', 'Bug'],
#  ['Poison', 'Dark'],
#  ['Poison', 'Fighting'],
#  ['Poison', 'Fighting'],
#  ['Grass', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', 'Flying'],
#  ['Grass', 'Ice'],
#  ['Grass', 'Ice'],
#  ['Grass', 'Ice'],
#  ['Dark', 'Ice'],
#  ['Electric', 'Steel'],
#  ['Normal', nan],
#  ['Ground', 'Rock'],
#  ['Grass', nan],
#  ['Electric', nan],
#  ['Fire', nan],
#  ['Fairy', 'Flying'],
#  ['Bug', 'Flying'],
#  ['Grass', nan],
#  ['Ice', nan],
#  ['Ground', 'Flying'],
#  ['Ice', 'Ground'],
#  ['Normal', nan],
#  ['Psychic', 'Fighting'],
#  ['Psychic', 'Fighting'],
#  ['Rock', 'Steel'],
#  ['Ghost', nan],
#  ['Ice', 'Ghost'],
#  ['Electric', 'Ghost'],
#  ['Electric', 'Fire'],
#  ['Electric', 'Water'],
#  ['Electric', 'Ice'],
#  ['Electric', 'Flying'],
#  ['Electric', 'Grass'],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Steel', 'Dragon'],
#  ['Water', 'Dragon'],
#  ['Fire', 'Steel'],
#  ['Normal', nan],
#  ['Ghost', 'Dragon'],
#  ['Ghost', 'Dragon'],
#  ['Psychic', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Dark', nan],
#  ['Grass', nan],
#  ['Grass', 'Flying'],
#  ['Normal', nan],
#  ['Psychic', 'Fire'],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Fire', nan],
#  ['Fire', 'Fighting'],
#  ['Fire', 'Fighting'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Dark', nan],
#  ['Dark', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Rock', nan],
#  ['Rock', nan],
#  ['Rock', nan],
#  ['Psychic', 'Flying'],
#  ['Psychic', 'Flying'],
#  ['Ground', nan],
#  ['Ground', 'Steel'],
#  ['Normal', nan],
#  ['Normal', 'Fairy'],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Water', nan],
#  ['Water', 'Ground'],
#  ['Water', 'Ground'],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Bug', 'Grass'],
#  ['Bug', 'Grass'],
#  ['Bug', 'Grass'],
#  ['Bug', 'Poison'],
#  ['Bug', 'Poison'],
#  ['Bug', 'Poison'],
#  ['Grass', 'Fairy'],
#  ['Grass', 'Fairy'],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Water', nan],
#  ['Ground', 'Dark'],
#  ['Ground', 'Dark'],
#  ['Ground', 'Dark'],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Fire', 'Psychic'],
#  ['Grass', nan],
#  ['Bug', 'Rock'],
#  ['Bug', 'Rock'],
#  ['Dark', 'Fighting'],
#  ['Dark', 'Fighting'],
#  ['Psychic', 'Flying'],
#  ['Ghost', nan],
#  ['Ghost', nan],
#  ['Water', 'Rock'],
#  ['Water', 'Rock'],
#  ['Rock', 'Flying'],
#  ['Rock', 'Flying'],
#  ['Poison', nan],
#  ['Poison', nan],
#  ['Dark', nan],
#  ['Dark', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Water', 'Flying'],
#  ['Water', 'Flying'],
#  ['Ice', nan],
#  ['Ice', nan],
#  ['Ice', nan],
#  ['Normal', 'Grass'],
#  ['Normal', 'Grass'],
#  ['Electric', 'Flying'],
#  ['Bug', nan],
#  ['Bug', 'Steel'],
#  ['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Water', 'Ghost'],
#  ['Water', 'Ghost'],
#  ['Water', nan],
#  ['Bug', 'Electric'],
#  ['Bug', 'Electric'],
#  ['Grass', 'Steel'],
#  ['Grass', 'Steel'],
#  ['Steel', nan],
#  ['Steel', nan],
#  ['Steel', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Ghost', 'Fire'],
#  ['Ghost', 'Fire'],
#  ['Ghost', 'Fire'],
#  ['Dragon', nan],
#  ['Dragon', nan],
#  ['Dragon', nan],
#  ['Ice', nan],
#  ['Ice', nan],
#  ['Ice', nan],
#  ['Bug', nan],
#  ['Bug', nan],
#  ['Ground', 'Electric'],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Dragon', nan],
#  ['Ground', 'Ghost'],
#  ['Ground', 'Ghost'],
#  ['Dark', 'Steel'],
#  ['Dark', 'Steel'],
#  ['Normal', nan],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Dark', 'Flying'],
#  ['Dark', 'Flying'],
#  ['Fire', nan],
#  ['Bug', 'Steel'],
#  ['Dark', 'Dragon'],
#  ['Dark', 'Dragon'],
#  ['Dark', 'Dragon'],
#  ['Bug', 'Fire'],
#  ['Bug', 'Fire'],
#  ['Steel', 'Fighting'],
#  ['Rock', 'Fighting'],
#  ['Grass', 'Fighting'],
#  ['Flying', nan],
#  ['Flying', nan],
#  ['Electric', 'Flying'],
#  ['Electric', 'Flying'],
#  ['Dragon', 'Fire'],
#  ['Dragon', 'Electric'],
#  ['Ground', 'Flying'],
#  ['Ground', 'Flying'],
#  ['Dragon', 'Ice'],
#  ['Dragon', 'Ice'],
#  ['Dragon', 'Ice'],
#  ['Water', 'Fighting'],
#  ['Water', 'Fighting'],
#  ['Normal', 'Psychic'],
#  ['Normal', 'Fighting'],
#  ['Bug', 'Steel'],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Grass', 'Fighting'],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Fire', 'Psychic'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', 'Dark'],
#  ['Normal', nan],
#  ['Normal', 'Ground'],
#  ['Normal', 'Flying'],
#  ['Fire', 'Flying'],
#  ['Fire', 'Flying'],
#  ['Bug', nan],
#  ['Bug', nan],
#  ['Bug', 'Flying'],
#  ['Fire', 'Normal'],
#  ['Fire', 'Normal'],
#  ['Fairy', nan],
#  ['Fairy', nan],
#  ['Fairy', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Fighting', nan],
#  ['Fighting', 'Dark'],
#  ['Normal', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Steel', 'Ghost'],
#  ['Steel', 'Ghost'],
#  ['Steel', 'Ghost'],
#  ['Steel', 'Ghost'],
#  ['Fairy', nan],
#  ['Fairy', nan],
#  ['Fairy', nan],
#  ['Fairy', nan],
#  ['Dark', 'Psychic'],
#  ['Dark', 'Psychic'],
#  ['Rock', 'Water'],
#  ['Rock', 'Water'],
#  ['Poison', 'Water'],
#  ['Poison', 'Dragon'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Electric', 'Normal'],
#  ['Electric', 'Normal'],
#  ['Rock', 'Dragon'],
#  ['Rock', 'Dragon'],
#  ['Rock', 'Ice'],
#  ['Rock', 'Ice'],
#  ['Fairy', nan],
#  ['Fighting', 'Flying'],
#  ['Electric', 'Fairy'],
#  ['Rock', 'Fairy'],
#  ['Dragon', nan],
#  ['Dragon', nan],
#  ['Dragon', nan],
#  ['Steel', 'Fairy'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ice', nan],
#  ['Ice', nan],
#  ['Flying', 'Dragon'],
#  ['Flying', 'Dragon'],
#  ['Fairy', nan],
#  ['Dark', 'Flying'],
#  ['Dragon', 'Ground'],
#  ['Rock', 'Fairy'],
#  ['Rock', 'Fairy'],
#  ['Psychic', 'Ghost'],
#  ['Psychic', 'Dark'],
#  ['Fire', 'Water']]

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
pokemon['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
pokemon['Name'].str.replace('[A-z]*Mega','Mega',regex = True)
#pokemon['Name'].apply(lambda x: re.sub('[A-z]*Mega','Mega', x))
pokemon.head()
# Out:
#    #           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3       Venusaur  Grass  Poison    525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4     Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 0       65     45           1      False   1.000000
# 1       80     60           1      False   0.984127
# 2      100     80           1      False   0.987952
# 3      120     80           1      False   0.813008
# 4       50     65           1      False   1.209302

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# your code here

pokemon['A/D Ratio'] = pokemon['Attack'] / pokemon['Defense']
max_ad_ratio = pokemon['A/D Ratio'].max()
pokemon.head()
# Out:
#    #           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3       Venusaur  Grass  Poison    525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4     Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 0       65     45           1      False   1.000000
# 1       80     60           1      False   0.984127
# 2      100     80           1      False   0.987952
# 3      120     80           1      False   0.813008
# 4       50     65           1      False   1.209302

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
# your code here       
highest = (pokemon[pokemon['A/D Ratio'] == max_ad_ratio] ['Name'])

highest =highest.to_frame()

highest
# Out:
#                    Name
# 429  DeoxysAttack Forme

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
lowest_ad_ratio = pokemon['A/D Ratio'].min()

lowest = (pokemon[pokemon['A/D Ratio'] == lowest_ad_ratio] ['Name'])

lowest =lowest.to_frame()

lowest
# Out:
#         Name
# 230  Shuckle

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
pokemon['Combo Type'] = pokemon['Type 1'] +'-' +pokemon['Type 2'].fillna('')
pokemon['Combo Type']= pokemon['Combo Type'].str.replace("-$","",regex=True)
pokemon
# Out:
#        #                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318  45      49       49
# 1      2              Ivysaur    Grass  Poison    405  60      62       63
# 2      3             Venusaur    Grass  Poison    525  80      82       83
# 3      3        Mega Venusaur    Grass  Poison    625  80     100      123
# 4      4           Charmander     Fire     NaN    309  39      52       43
# ..   ...                  ...      ...     ...    ...  ..     ...      ...
# 795  719              Diancie     Rock   Fairy    600  50     100      150
# 796  719         Mega Diancie     Rock   Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721            Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio     Combo Type
# 0         65       65     45           1      False   1.000000   Grass-Poison
# 1         80       80     60           1      False   0.984127   Grass-Poison
# 2        100      100     80           1      False   0.987952   Grass-Poison
# 3        122      120     80           1      False   0.813008   Grass-Poison
# 4         60       50     65           1      False   1.209302           Fire
# ..       ...      ...    ...         ...        ...        ...            ...
# 795      100      150     50           6       True   0.666667     Rock-Fairy
# 796      160      110    110           6       True   1.454545     Rock-Fairy
# 797      150      130     70           6       True   1.833333  Psychic-Ghost
# 798      170      130     80           6       True   2.666667   Psychic-Dark
# 799      130       90     70           6       True   0.916667     Fire-Water
#
# [800 rows x 15 columns]

# %%
# your code here
print(pokemon['Combo Type'].tolist())
# Out:
# ['Grass-Poison', 'Grass-Poison', 'Grass-Poison', 'Grass-Poison', 'Fire', 'Fire', 'Fire-Flying', 'Fire-Dragon', 'Fire-Flying', 'Water', 'Water', 'Water', 'Water', 'Bug', 'Bug', 'Bug-Flying', 'Bug-Poison', 'Bug-Poison', 'Bug-Poison', 'Bug-Poison', 'Normal-Flying', 'Normal-Flying', 'Normal-Flying', 'Normal-Flying', 'Normal', 'Normal', 'Normal-Flying', 'Normal-Flying', 'Poison', 'Poison', 'Electric', 'Electric', 'Ground', 'Ground', 'Poison', 'Poison', 'Poison-Ground', 'Poison', 'Poison', 'Poison-Ground', 'Fairy', 'Fairy', 'Fire', 'Fire', 'Normal-Fairy', 'Normal-Fairy', 'Poison-Flying', 'Poison-Flying', 'Grass-Poison', 'Grass-Poison', 'Grass-Poison', 'Bug-Grass', 'Bug-Grass', 'Bug-Poison', 'Bug-Poison', 'Ground', 'Ground', 'Normal', 'Normal', 'Water', 'Water', 'Fighting', 'Fighting', 'Fire', 'Fire', 'Water', 'Water', 'Water-Fighting', 'Psychic', 'Psychic', 'Psychic', 'Psychic', 'Fighting', 'Fighting', 'Fighting', 'Grass-Poison', 'Grass-Poison', 'Grass-Poison', 'Water-Poison', 'Water-Poison', 'Rock-Ground', 'Rock-Ground', 'Rock-Ground', 'Fire', 'Fire', 'Water-Psychic', 'Water-Psychic', 'Water-Psychic', 'Electric-Steel', 'Electric-Steel', 'Normal-Flying', 'Normal-Flying', 'Normal-Flying', 'Water', 'Water-Ice', 'Poison', 'Poison', 'Water', 'Water-Ice', 'Ghost-Poison', 'Ghost-Poison', 'Ghost-Poison', 'Ghost-Poison', 'Rock-Ground', 'Psychic', 'Psychic', 'Water', 'Water', 'Electric', 'Electric', 'Grass-Psychic', 'Grass-Psychic', 'Ground', 'Ground', 'Fighting', 'Fighting', 'Normal', 'Poison', 'Poison', 'Ground-Rock', 'Ground-Rock', 'Normal', 'Grass', 'Normal', 'Normal', 'Water', 'Water', 'Water', 'Water', 'Water', 'Water-Psychic', 'Psychic-Fairy', 'Bug-Flying', 'Ice-Psychic', 'Electric', 'Fire', 'Bug', 'Bug-Flying', 'Normal', 'Water', 'Water-Flying', 'Water-Dark', 'Water-Ice', 'Normal', 'Normal', 'Water', 'Electric', 'Fire', 'Normal', 'Rock-Water', 'Rock-Water', 'Rock-Water', 'Rock-Water', 'Rock-Flying', 'Rock-Flying', 'Normal', 'Ice-Flying', 'Electric-Flying', 'Fire-Flying', 'Dragon', 'Dragon', 'Dragon-Flying', 'Psychic', 'Psychic-Fighting', 'Psychic', 'Psychic', 'Grass', 'Grass', 'Grass', 'Fire', 'Fire', 'Fire', 'Water', 'Water', 'Water', 'Normal', 'Normal', 'Normal-Flying', 'Normal-Flying', 'Bug-Flying', 'Bug-Flying', 'Bug-Poison', 'Bug-Poison', 'Poison-Flying', 'Water-Electric', 'Water-Electric', 'Electric', 'Fairy', 'Normal-Fairy', 'Fairy', 'Fairy-Flying', 'Psychic-Flying', 'Psychic-Flying', 'Electric', 'Electric', 'Electric', 'Electric-Dragon', 'Grass', 'Water-Fairy', 'Water-Fairy', 'Rock', 'Water', 'Grass-Flying', 'Grass-Flying', 'Grass-Flying', 'Normal', 'Grass', 'Grass', 'Bug-Flying', 'Water-Ground', 'Water-Ground', 'Psychic', 'Dark', 'Dark-Flying', 'Water-Psychic', 'Ghost', 'Psychic', 'Psychic', 'Normal-Psychic', 'Bug', 'Bug-Steel', 'Normal', 'Ground-Flying', 'Steel-Ground', 'Steel-Ground', 'Fairy', 'Fairy', 'Water-Poison', 'Bug-Steel', 'Bug-Steel', 'Bug-Rock', 'Bug-Fighting', 'Bug-Fighting', 'Dark-Ice', 'Normal', 'Normal', 'Fire', 'Fire-Rock', 'Ice-Ground', 'Ice-Ground', 'Water-Rock', 'Water', 'Water', 'Ice-Flying', 'Water-Flying', 'Steel-Flying', 'Dark-Fire', 'Dark-Fire', 'Dark-Fire', 'Water-Dragon', 'Ground', 'Ground', 'Normal', 'Normal', 'Normal', 'Fighting', 'Fighting', 'Ice-Psychic', 'Electric', 'Fire', 'Normal', 'Normal', 'Electric', 'Fire', 'Water', 'Rock-Ground', 'Rock-Ground', 'Rock-Dark', 'Rock-Dark', 'Psychic-Flying', 'Fire-Flying', 'Psychic-Grass', 'Grass', 'Grass', 'Grass', 'Grass-Dragon', 'Fire', 'Fire-Fighting', 'Fire-Fighting', 'Fire-Fighting', 'Water', 'Water-Ground', 'Water-Ground', 'Water-Ground', 'Dark', 'Dark', 'Normal', 'Normal', 'Bug', 'Bug', 'Bug-Flying', 'Bug', 'Bug-Poison', 'Water-Grass', 'Water-Grass', 'Water-Grass', 'Grass', 'Grass-Dark', 'Grass-Dark', 'Normal-Flying', 'Normal-Flying', 'Water-Flying', 'Water-Flying', 'Psychic-Fairy', 'Psychic-Fairy', 'Psychic-Fairy', 'Psychic-Fairy', 'Bug-Water', 'Bug-Flying', 'Grass', 'Grass-Fighting', 'Normal', 'Normal', 'Normal', 'Bug-Ground', 'Bug-Flying', 'Bug-G ...

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
pokemon.sort_values(by = 'A/D Ratio', ascending=False, inplace=False)
# Out:
#        #                Name   Type 1   Type 2  Total   HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic      NaN    600   50     180       20
# 347  318            Carvanha    Water     Dark    305   45      90       20
# 19    15       Mega Beedrill      Bug   Poison    495   65     150       40
# 453  408            Cranidos     Rock      NaN    350   67     125       40
# 348  319            Sharpedo    Water     Dark    460   70     120       40
# ..   ...                 ...      ...      ...    ...  ...     ...      ...
# 616  555  DarmanitanZen Mode     Fire  Psychic    540  105      30      105
# 103   95                Onix     Rock   Ground    385   35      45      160
# 484  436             Bronzor    Steel  Psychic    300   57      24       86
# 139  129            Magikarp    Water      NaN    200   20      10       55
# 230  213             Shuckle      Bug     Rock    505   20      10      230
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio     Combo Type
# 429      180       20    150           3       True   9.000000        Psychic
# 347       65       20     65           3      False   4.500000     Water-Dark
# 19        15       80    145           1      False   3.750000     Bug-Poison
# 453       30       30     58           4      False   3.125000           Rock
# 348       95       40     95           3      False   3.000000     Water-Dark
# ..       ...      ...    ...         ...        ...        ...            ...
# 616      140      105     55           5      False   0.285714   Fire-Psychic
# 103       30       45     70           1      False   0.281250    Rock-Ground
# 484       24       86     23           4      False   0.279070  Steel-Psychic
# 139       15       20     80           1      False   0.181818          Water
# 230       10      230      5           2      False   0.043478       Bug-Rock
#
# [800 rows x 15 columns]

# %%
sorted_5 = pokemon.sort_values(by = 'A/D Ratio', ascending=False, inplace=False)

highest_5 = sorted_5[['A/D Ratio', 'Name','Combo Type']]
highest_5.head()
# Out:
#      A/D Ratio                Name  Combo Type
# 429      9.000  DeoxysAttack Forme     Psychic
# 347      4.500            Carvanha  Water-Dark
# 19       3.750       Mega Beedrill  Bug-Poison
# 453      3.125            Cranidos        Rock
# 348      3.000            Sharpedo  Water-Dark

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
print(highest_5['Combo Type'][0:4].to_list())
# Out:
# ['Psychic', 'Water-Dark', 'Bug-Poison', 'Rock']

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)
